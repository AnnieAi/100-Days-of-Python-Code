# %%
from tkinter import *
import math

# %% [markdown]
# # CONSTANTS

# %%
PINK = "#e2979c"
RED = "#e7305b"
GREEN = "#9bdeac"
YELLOW = "#f7f5dd"
FONT_NAME = "Courier"
WORK_MIN = 25
SHORT_BREAK_MIN = 5
LONG_BREAK_MIN = 20

# %% [markdown]
# # TIMER MECHANISM

# %%
def start_timer():
    count_down(5 * 60)

# %% [markdown]
# 这个函数的作用就是输入给button的command，然后从这个函数进去调用函数`count_down`。
#
# count_down是需要传参的，但是加给button的command的只是函数对象，不能传参，所以要多修一层装饰、入口？用这个方法来实现按下按钮就能开始countdown。

# %% [markdown]
# # COUNTDOWN MECHANISM

# %% [markdown]
# # 217 DYNAMIC TYPING

# %%
def count_down(count):

    count_min = math.floor(count / 60)
    count_sec = count % 60
    if count_sec < 10:
        # count_sec = "0" + str(count_sec)
        count_sec = f"0{count_sec}"
    
    canvas.itemconfig(timer_text, text=f"{count_min}:{count_sec}")
    
    if count > 0:   # count = 0时，停止递归（使用递归时需要设置终止语句）
        window.after(1000, count_down, count - 1)     # 1000 毫秒后，调用 count_down(count - 1)

# %% [markdown]
# ### 要点1  当秒数小于10的时候，要输出09 08 07而不是9 8 7
#
# #### 方法1 字符串拼接
# `count_sec = "0" + str(count_sec)`
#
# #### 方法2 f-string
# `count_sec = f"0{count_sec}"`

# %% [markdown]
# ### 要点2 Dynamic Typing: 变量名本身不固定类型，类型属于它当前指向的对象
#
# 集中在这段：
# ```python
# count_sec = count % 60
#
# if count_sec < 10:
#     count_sec = f"0{count_sec}"
#
# canvas.itemconfig(timer_text, text=f"{count_min}:{count_sec}")
# ```
#
# `count_sec` 一开始是 `int`，例如 `9`；
#
# 如果 `count_sec < 10`，就用 `f"0{count_sec}"` 把它变成 `str`，例如 `"09"`。
#
# 能这么做的原因是 Python 是动态类型语言，变量名的作用更像指针，而不是像C里面那样负责存东西。

# %% [markdown]
# # UI SETUP

# %% [markdown]
# ## Window

# %%
# Window
window = Tk()
window.title("Pomodoro")
window.config(padx=100, pady=50, bg=YELLOW)

## Label1
timer_label = Label(text="Timer", font=(FONT_NAME, 50), fg=GREEN, bg=YELLOW)
timer_label.grid(column=1, row=0)

## Canvas
canvas = Canvas(width=200, height=224, bg=YELLOW, highlightthickness=0)
tomato_img = PhotoImage(file="tomato.png")
canvas.create_image(100, 112, image=tomato_img)
timer_text = canvas.create_text(100, 130, text="00:00", fill="white", font=(FONT_NAME, 35, "bold"))
canvas.grid(column=1, row=1)

## Button1
start_button = Button(text="Start", highlightthickness=0, command=start_timer)
start_button.grid(column=0, row=2)

## Button2
reset_button = Button(text="Reset", highlightthickness=0)
reset_button.grid(column=2, row=2)

# Label2
check_marks = Label(text="✔", fg=GREEN, bg=YELLOW)
check_marks.grid(column=1, row=3)

window.mainloop()
